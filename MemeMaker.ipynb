# %% [markdown]
# <a href="https://colab.research.google.com/github/mso888/girlscouts/blob/main/MemeMaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import urllib
import cv2
def url_to_image(url):
    req = urllib.request.Request(
        url= url, 
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    resp = urllib.request.urlopen(req)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    return image

# font
font = cv2.FONT_HERSHEY_SIMPLEX
  
# org
org = (100, 100)
  
# fontScale
fontScale = 1
   
# Blue color in BGR
color = (255, 0, 0)
  
# Line thickness of 2 px
thickness = 2
   
img = url_to_image('https://bit.ly/3Vigt2q')
# Using cv2.putText() method
img = cv2.putText(img, 'WHAT IF DITTO WAS REALLY FLUBBER?', org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)

# Output img with window name as 'image'
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=968x768 at 0x7F787E30AE10>
